# %%
# Mount theh google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Example 3.1

# %%
#Example 3.1
#Import the Growth_Value data and label it myData

import pandas as pd
myData = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/MH-Ch3/jaggia_ba_2025_ch03_data.xlsx', sheet_name = 'Growth_Value')
myData.head(n=10)
# Out:
#    Year  Growth  Value
# 0  1984   -5.50  -8.59
# 1  1985   39.91  22.10
# 2  1986   13.03  14.74
# 3  1987   -1.70  -8.58
# 4  1988   16.05  29.05
# 5  1989   41.64  22.95
# 6  1990    3.59 -12.82
# 7  1991   48.33  26.20
# 8  1992    7.94  21.15
# 9  1993   16.19  22.94

# %%
#Calculate the mean, median, and mode for Growth
print(myData.Growth.mean())
print(myData.Growth.median())
print(myData.Growth.mode())
# Out:
# 15.989230769230767
# 16.05
# 0    -40.90
# 1    -33.78
# 2    -33.45
# 3    -25.31
# 4     -6.32
# 5     -5.50
# 6     -4.53
# 7     -2.22
# 8     -1.70
# 9      0.67
# 10     3.59
# 11     6.01
# 12     7.83
# 13     7.94
# 14     9.56
# 15    12.12
# 16    13.03
# 17    13.50
# 18    14.44
# 19    16.05
# 20    16.19
# 21    16.81
# 22    18.52
# 23    18.91
# 24    19.89
# 25    20.55
# 26    22.67
# 27    27.23
# 28    36.76
# 29    37.61
# 30    38.42
# 31    39.61
# 32    39.91
# 33    41.15
# 34    41.36
# 35    41.64
# 36    48.33
# 37    67.51
# 38    79.48
# Name: Growth, dtype: float64

# %%
#Another alternative expression
myData["Growth"].mean()
myData['Growth'].median()
# Out:
# 16.05

# %%
#Calculate the mean, median, and mode for Value
print(myData.Value.mean())
print(myData.Value.median())
print(myData.Value.mode())
# Out:
# 11.996410256410257
# 15.09
# 0    -46.52
# 1    -17.34
# 2    -12.82
# 3     -9.25
# 4     -9.01
# 5     -8.59
# 6     -8.58
# 7     -6.71
# 8     -6.51
# 9      0.18
# 10     2.21
# 11     7.63
# 12     8.10
# 13     8.55
# 14     9.31
# 15    11.72
# 16    12.25
# 17    14.27
# 18    14.74
# 19    15.09
# 20    15.67
# 21    16.06
# 22    16.85
# 23    21.08
# 24    21.15
# 25    21.21
# 26    21.90
# 27    22.10
# 28    22.27
# 29    22.94
# 30    22.95
# 31    26.20
# 32    27.13
# 33    29.05
# 34    31.62
# 35    34.43
# 36    35.38
# 37    37.07
# 38    44.08
# Name: Value, dtype: float64

# %%
print(myData.describe())
# Out:
#               Year     Growth     Value
# count    39.000000  39.000000  39.00000
# mean   2003.000000  15.989231  11.99641
# std      11.401754  25.650579  17.99786
# min    1984.000000 -40.900000 -46.52000
# 25%    1993.500000   2.130000   1.19500
# 50%    2003.000000  16.050000  15.09000
# 75%    2012.500000  37.185000  22.60500
# max    2022.000000  79.480000  44.08000

# %% [markdown]
# ## Example 3.2

# %%
# Example 3.2
# Import the Online data file and label it myData

import pandas as pd
myData = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/MH-Ch3/jaggia_ba_2025_ch03_data.xlsx', sheet_name = 'Online')
myData.head(n=10)
# Out:
#    Customer     Sex  Clothing  Health  Tech  Misc
# 0         1  Female       246     185    64    75
# 1         2    Male       171      78   345    10
# 2         3  Female        95      15    47    90
# 3         4    Male       125      16   493    13
# 4         5  Female       368     100    82   109
# 5         6    Male       148     139   347   107
# 6         7    Male        48      74   108   176
# 7         8    Male       147     108   532   146
# 8         9  Female        91      46    86   182
# 9        10  Female       324      80    12    51

# %%
myData.groupby('Sex').agg('mean')
# Out:
#          Customer    Clothing      Health        Tech        Misc
# Sex
# Female  67.375000  225.666667  100.250000   47.097222  159.875000
# Male    63.172414   97.931034  100.637931  310.965517   85.844828

# %%
myData.groupby('Sex').mean()  #Another expression --> we learned this in chapter 2
# Out:
#          Customer    Clothing      Health        Tech        Misc
# Sex
# Female  67.375000  225.666667  100.250000   47.097222  159.875000
# Male    63.172414   97.931034  100.637931  310.965517   85.844828

# %%
myData.groupby('Sex').mean().round(2)
# Out:
#         Customer  Clothing  Health    Tech    Misc
# Sex
# Female     67.38    225.67  100.25   47.10  159.88
# Male       63.17     97.93  100.64  310.97   85.84

# %%
# Note: Calculating the average/mean of the Customer column is meaningless --> Remove the column!
# drop ( ..., axis = 1)  --> axix = 1 in drop method() --> remove the column, not row!
# Note that the orginal data frame, myData won't be changed at all. The drop() returns a new dataframe.

myData.drop('Customer', axis = 1).groupby('Sex').agg('mean').round(2)
# Out:
#         Clothing  Health    Tech    Misc
# Sex
# Female    225.67  100.25   47.10  159.88
# Male       97.93  100.64  310.97   85.84

# %%
#Another way to drop  Customer column.
#Create another new variable, groupby_sex:

groupby_sex = myData.groupby('Sex').agg('mean').round(2)
print(groupby_sex)

groupby_sex_no_customer = groupby_sex.drop('Customer', axis = 1)
print(groupby_sex_no_customer)
# Out:
#         Customer  Clothing  Health    Tech    Misc
# Sex
# Female     67.38    225.67  100.25   47.10  159.88
# Male       63.17     97.93  100.64  310.97   85.84
#         Clothing  Health    Tech    Misc
# Sex
# Female    225.67  100.25   47.10  159.88
# Male       97.93  100.64  310.97   85.84

# %% [markdown]
# ## Example 3.3

# %%
#Example 3.3
#Import the Growth_Value data file and label it myData

import pandas as pd
myData = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/MH-Ch3/jaggia_ba_2025_ch03_data.xlsx', sheet_name = 'Growth_Value')
myData.head(n=10)
# Out:
#    Year  Growth  Value
# 0  1984   -5.50  -8.59
# 1  1985   39.91  22.10
# 2  1986   13.03  14.74
# 3  1987   -1.70  -8.58
# 4  1988   16.05  29.05
# 5  1989   41.64  22.95
# 6  1990    3.59 -12.82
# 7  1991   48.33  26.20
# 8  1992    7.94  21.15
# 9  1993   16.19  22.94

# %%
print(myData.describe())

# quantile(0.3) returns the 30th percentile of the Growth column
print(myData.Growth.quantile(0.30))
# Out:
#               Year     Growth     Value
# count    39.000000  39.000000  39.00000
# mean   2003.000000  15.989231  11.99641
# std      11.401754  25.650579  17.99786
# min    1984.000000 -40.900000 -46.52000
# 25%    1993.500000   2.130000   1.19500
# 50%    2003.000000  16.050000  15.09000
# 75%    2012.500000  37.185000  22.60500
# max    2022.000000  79.480000  44.08000
# 6.738

# %% [markdown]
# # Growth.quantile(0.30)
#
# 1. Take the numeric values in myData["Growth"] and ignore any NaNs (they’re dropped by default).
#
# 2. Sort the remaining values from smallest to largest.
#
# 3. Find the position (or index) p = (n-1) * 0.3, where n is the number of (non-NaN) values.  Note p stands for index (index starts from 0)
#
# 4.  p isn’t an integer, interpolate linearly between the two surrounding values (this is the default behavior).

# %% [markdown]
# ## Exzmple 3.4

# %%
#Example 3.4
#Import the Growth_Value data file and label it myData

import pandas as pd
myData = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/MH-Ch3/jaggia_ba_2025_ch03_data.xlsx', sheet_name = 'Growth_Value')
myData
# Out:
#     Year  Growth  Value
# 0   1984   -5.50  -8.59
# 1   1985   39.91  22.10
# 2   1986   13.03  14.74
# 3   1987   -1.70  -8.58
# 4   1988   16.05  29.05
# 5   1989   41.64  22.95
# 6   1990    3.59 -12.82
# 7   1991   48.33  26.20
# 8   1992    7.94  21.15
# 9   1993   16.19  22.94
# 10  1994   -2.22   7.63
# 11  1995   39.61  27.13
# 12  1996   16.81  16.85
# 13  1997   18.91  21.08
# 14  1998   27.23   0.18
# 15  1999   79.48   8.55
# 16  2000   -6.32   8.10
# 17  2001  -25.31  12.25
# 18  2002  -33.45  -9.25
# 19  2003   41.36  34.43
# 20  2004   12.12  21.21
# 21  2005   13.50  14.27
# 22  2006    9.56  15.09
# 23  2007   19.89   2.21
# 24  2008  -40.90 -46.52
# 25  2009   41.15  44.08
# 26  2010   20.55  22.27
# 27  2011    0.67  -6.71
# 28  2012   18.52  21.90
# 29  2013   37.61  37.07
# 30  2014   14.44  11.72
# 31  2015    7.83  -6.51
# 32  2016    6.01  16.06
# 33  2017   36.76  15.67
# 34  2018   -4.53 -17.34
# 35  2019   38.42  31.62
# 36  2020   67.51   9.31
# ...

# %%
# Calculating measures of dispersion for Growth
print(myData.Growth.max() - myData.Growth.min())  # Range

print(myData.Growth.quantile(.75) - myData.Growth.quantile(.25)) #IQR of column Growth

print(    (abs  (myData.Growth-myData.Growth.mean()  )   ).mean()) #Mean Absoluate Deviation About the mean

print(myData.Growth.var()) # By default, Sample variance as ddof =1;

print(myData.Growth.std()) # By default, Sample std, not population std




print(myData.Growth.std()/myData.Growth.mean()) # CV --> Coefficient Variation
# Out:
# 120.38
# 35.055
# 18.91360946745562
# 657.9521914979758
# 25.650578775107117
# 1.6042409510073732

# %%
# Value column

myData.Value.var() #sample variance of the column, Value
# Out:
# 323.92294993252364

# %%
# Calculating measures of dispersion for Value
print(myData.Value.max() - myData.Value.min())

print(myData.Value.quantile(.75) - myData.Value.quantile(.25))

print((abs(myData.Value-myData.Value.mean())).mean())

print(myData.Value.var())

print(myData.Value.std())

print(myData.Value.std()/myData.Value.mean())

# %% [markdown]
# ## Example 3.7

# %%
import pandas as pd
myData = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/MH-Ch3/jaggia_ba_2025_ch03_data.xlsx', sheet_name = 'Growth_Value')
myData
# Out:
#     Year  Growth  Value
# 0   1984   -5.50  -8.59
# 1   1985   39.91  22.10
# 2   1986   13.03  14.74
# 3   1987   -1.70  -8.58
# 4   1988   16.05  29.05
# 5   1989   41.64  22.95
# 6   1990    3.59 -12.82
# 7   1991   48.33  26.20
# 8   1992    7.94  21.15
# 9   1993   16.19  22.94
# 10  1994   -2.22   7.63
# 11  1995   39.61  27.13
# 12  1996   16.81  16.85
# 13  1997   18.91  21.08
# 14  1998   27.23   0.18
# 15  1999   79.48   8.55
# 16  2000   -6.32   8.10
# 17  2001  -25.31  12.25
# 18  2002  -33.45  -9.25
# 19  2003   41.36  34.43
# 20  2004   12.12  21.21
# 21  2005   13.50  14.27
# 22  2006    9.56  15.09
# 23  2007   19.89   2.21
# 24  2008  -40.90 -46.52
# 25  2009   41.15  44.08
# 26  2010   20.55  22.27
# 27  2011    0.67  -6.71
# 28  2012   18.52  21.90
# 29  2013   37.61  37.07
# 30  2014   14.44  11.72
# 31  2015    7.83  -6.51
# 32  2016    6.01  16.06
# 33  2017   36.76  15.67
# 34  2018   -4.53 -17.34
# 35  2019   38.42  31.62
# 36  2020   67.51   9.31
# ...

# %%
myData[['Growth','Value']].corr() # Correlation Coefficient --> 0.63
# Out:
#          Growth    Value
# Growth  1.00000  0.63042
# Value   0.63042  1.00000

# %%
myData[['Growth','Value']].cov() # Covariance --> 291.03
# Out:
#             Growth       Value
# Growth  657.952191  291.036989
# Value   291.036989  323.922950

# %% [markdown]
# ## Section 3.3 Detecting Outliers: **Boxplots**

# %% [markdown]
# ### Example 3.8 (enhanced the example by adding more contents and remove a few lines of code)

# %%
import pandas as pd
import matplotlib.pyplot as plt

myData = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/MH-Ch3/jaggia_ba_2025_ch03_data.xlsx', sheet_name = 'Growth_Value')
myData.head()
# Out:
#    Year  Growth  Value
# 0  1984   -5.50  -8.59
# 1  1985   39.91  22.10
# 2  1986   13.03  14.74
# 3  1987   -1.70  -8.58
# 4  1988   16.05  29.05

# %%
# Draw the box plot
BoxPlot1 = myData.boxplot(column = ['Growth', 'Value'], vert = True)  # vert = true -> vertical boxplots
BoxPlot1.set(ylabel = 'Annual Returns (in %)') #set the y label
plt.show()

# %% [markdown]
# ### What the box shows
#
# *   Q1 (25th percentile) to Q3 (75th percentile) make the box.
#
# *   The line inside is the median (50th percentile).
#
# *   IQR = Q3 − Q1 is the box’s height: it’s the spread of the middle 50%.
#
# *   Whisker_low & Whisker_high
#
# *   outlier(s)
#
#
# ### Whiskers & Fence (what they really mean)
#
# By default, whiskers do not go to the true min/max. They extend from the box to the most extreme data points that are not outliers:
#
# * **Lower fence**: $Q_1 -1.5 * IQR $
#
#
# * **Upper fence**:$Q_3 + 1.5 * IQR$
#
#
# The whiskers end at the closest observed values **within those fences** (sometimes called “adjacent values”).
#
# ### Outliers
# * Any point below the lower fense and any point above the upper fense
#
# ### Min and Max - Careful Observation
#
# * If there is no outliers, whisker endpoints equal the acutal min and max.
# * If there are outliers, whiskers stop short, and the acutal min/max apper as outlier points beyond the whiskers.

# %% [markdown]
# ### Another simple example

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example data
exam_score = pd.DataFrame({
    "midterm": [65, 71, 72, 48, 55, 25, 55, 45, 37, 43, 58, 65, 57, 59, 9,100],
    "final":   [60, 68, 64, 55, 59, 45, 66,55, 38, 52, 54,34, 98, 43, 99,100]
})

# %%
# --- Box plot (vertical) ---
BoxPlot1 = exam_score.boxplot(column=['midterm', 'final'], vert=True)
BoxPlot1.set(ylabel='Scores', title='Exam Scores: Midterm vs Final')
plt.show()

# %%
s = exam_score.dropna() #drop the rows with NaN (missing values) and store the result in s

# %%
q1_midterm = s['midterm'].quantile(0.25)
med_midterm = s['midterm'].quantile(0.50)
q3_midterm  = s['midterm'].quantile(0.75)
IQR_midterm = q3_midterm - q1_midterm

lower_fence_midterm = q1_midterm - 1.5 * IQR_midterm
upper_fence_midterm = q3_midterm + 1.5 * IQR_midterm


print("min:", s['midterm'].min())
print("Q1:", q1_midterm)
print("median:", med_midterm)
print("Q3:", q3_midterm)
print("IQR:", IQR_midterm)

print("low_fence:", lower_fence_midterm) #Low fence value
print("High_fense:", upper_fence_midterm) #High fence value
# Out:
# min: 9
# Q1: 44.5
# median: 56.0
# Q3: 65.0
# IQR: 20.5
# low_fence: 13.75
# High_fense: 95.75

# %%
#midterm scores less than the upper_fence_midterm to find the whisker_high
s['midterm'] <= upper_fence_midterm #list of Trues/Falses
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15    False
# Name: midterm, dtype: bool

# %%
# find the high whisker value for the midterm

midterm_less_than_upper_fence = s[s['midterm'] <= upper_fence_midterm]

# Among the midterm scores less than the midterm score upper fence, find the max value
whisker_high_midterm = midterm_less_than_upper_fence['midterm'].max()

print(whisker_high_midterm)
# Out:
# 72

# %%
# find the low whisker value for the midterm
midterm_higher_than_lower_fence = s[s['midterm'] >= lower_fence_midterm]
whisker_low_midterm = midterm_higher_than_lower_fence['midterm'].min()
print(whisker_low_midterm)
# Out:
# 25

# %%
#Find the outliers if any

# Any values greater than the higher fence

high_outlier = s[s['midterm'] >= upper_fence_midterm]
print(high_outlier)
print( "******************************")

low_outlier = s[s['midterm'] <= lower_fence_midterm]
print(low_outlier)
# Out:
#     midterm  final
# 15      100    100
# ******************************
#     midterm  final
# 14        9     99
