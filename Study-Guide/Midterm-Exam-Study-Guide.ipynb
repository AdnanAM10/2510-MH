# %% [markdown]
# #Midterm Exam Study Guide

# %% [markdown]
# ## Python Review

# %%
#list
num = [1,2,3]
print(num[0]) #index starts at 0

print(len(num))

num.append(4) #append 4 to the tail of the list, num
print(num)

#change the 2nd element to 100
num[1] = 100

print(num)
# Out:
# 1
# 3
# [1, 2, 3, 4]
# [1, 100, 3, 4]

# %%
#dictionary

score = {'kevin':100, 'james':81}

#add jessica and her midterm score, 85

score['jessica'] = 85

#update the jame's midtermm score from 81 to 86

score['james'] = 86

score
# Out:
# {'kevin': 100, 'james': 86, 'jessica': 85}

# %%
# Function -> Reivew function_quiz assigment (focus on problem # 3 and problem #4, ignore problem #2)

def xyz (x, y=10, z=False):
  print(x, y, z)
  return x

a=10
xyz(a)

xyz(a, 100, True)
# Out:
# 10 10 False
# 10 100 True
# 10

# %% [markdown]
# *italicized text*

# %%
import pandas as pd
grade = pd.DataFrame({
    "quiz1": [100, 84, 58],
    "quiz2": [92, 77, 65],
    "quiz3": [85, 90, 70],
})

print(grade.quiz1.std()) #sample std deviation of quiz1 column  -> .notation
print("****************")
print(grade[['quiz1']].std())  # same expression --> same result as above. -> bracket notation
print("***************")
print(grade.var()) #sample var for each column
# Out:
# 21.197484127446195
# ****************
# quiz1    21.197484
# dtype: float64
# ***************
# quiz1    449.333333
# quiz2    183.000000
# quiz3    108.333333
# dtype: float64

# %%
#Column subsetting!

import pandas as pd

employee = pd.DataFrame({
    "Name": ["Jame", "Kate", "Omar", "Mei", "Luis"],
    "Age": [19, 24, 21, 28, 32],
    "City": ["Austin", "Riverside", "San Jose" , "Seattle", "Portland"],  # blank city as pd.NA
    "HoursWorked": [40, 45, 35, 50, 30],
})

print(employee)

print("*******************")

#all return the same result ; single column subsetting
print(employee[["Name"]])
print(employee['Name'])
print(employee.Name)

# Multiple column subseeting

print(employee[['Name', 'City']])
# Out:
#    Name  Age       City  HoursWorked
# 0  Jame   19     Austin           40
# 1  Kate   24  Riverside           45
# 2  Omar   21   San Jose           35
# 3   Mei   28    Seattle           50
# 4  Luis   32   Portland           30
# *******************
#    Name
# 0  Jame
# 1  Kate
# 2  Omar
# 3   Mei
# 4  Luis
# 0    Jame
# 1    Kate
# 2    Omar
# 3     Mei
# 4    Luis
# Name: Name, dtype: object
# 0    Jame
# 1    Kate
# 2    Omar
# 3     Mei
# 4    Luis
# Name: Name, dtype: object
#    Name       City
# 0  Jame     Austin
# 1  Kate  Riverside
# 2  Omar   San Jose
# 3   Mei    Seattle
# 4  Luis   Portland

# %%
# Row subsetting

#Return the second and third rows
print(employee.iloc[1:3])  #integer based

print('************')
print(employee.loc[1:2]) #label based


#first three rows and and the columns, Name and City
print("*********")
print(employee.loc[0:2, ['Name', 'City']])
print("*********")
print(employee.iloc[0:3, [0,2]])
# Out:
#    Name  Age       City  HoursWorked
# 1  Kate   24  Riverside           45
# 2  Omar   21   San Jose           35
# ************
#    Name  Age       City  HoursWorked
# 1  Kate   24  Riverside           45
# 2  Omar   21   San Jose           35
# *********
#    Name       City
# 0  Jame     Austin
# 1  Kate  Riverside
# 2  Omar   San Jose
# *********
#    Name       City
# 0  Jame     Austin
# 1  Kate  Riverside
# 2  Omar   San Jose

# %% [markdown]
# Review the last topic (Boxplot)
#
# 1.   Q1, Q2, Q3, IQR
# 2.   Upper fense, lower fense
# 3.   Low whisker, high whisker
# 4.   Outliers

# %% [markdown]
# - study isnull() function
# - fillna
# -
