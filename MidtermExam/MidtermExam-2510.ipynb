# %% [markdown]
# # MidtermExam-2510 Hint Code & Setup
#
# Midtermexam-2510 is the official hint code for the midterm. Many exam questions are based on it.
#
# **Before the exam**
#
# *  Mount your Google Drive in Colab.
#
# *  Place midterm-customer.csv in a folder you can access from the Drive mount (e.g., /content/drive/MyDrive/midterm/).
#
# * Open Midtermexam-2510, update the file path to the CSV if needed, and make sure the notebook runs end-to-end without errors.
#
# **During the exam**
#
# * You will run the hint code and **edit/modify/expand** it to answer the questions.
#
#
# If you can run the notebook and load midterm-customer.csv from your Drive mount, you’re ready.

# %%
#mounnt your google dirve
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
myData = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/MidtermExam/midterm-customer.csv')
myData.head(n=5)
# Out:
#     CustID     Sex      Race   BirthDate College  HouseholdSize  ZipCode  \
# 0  1530016  Female     Black  12/16/1986     Yes              5    90047
# 1  1531136    Male     White    5/9/1993     Yes              5    90026
# 2  1532160    Male     Black   5/22/1966     Yes              2    90027
# 3  1532307    Male     White   9/16/1964     Yes              4    90029
# 4  1532356  Female  Hispanic   7/15/1964      No              5    90017
#
#    Income  Spending2020  Spending2021  NumOfOrders  DaysSinceLast  \
# 0   53000         287.0         241.0            3            101
# 1   94000        1227.0         843.0           12            262
# 2   64000         523.0         719.0            9            122
# 3   60000         516.0         582.0           13            129
# 4   47000         555.0         845.0            7             97
#
#         Satisfaction Channel
# 0  Very Dissatisfied      SM
# 1            Neutral      TV
# 2     Very Satisfied      TV
# 3  Very Dissatisfied      SM
# 4  Very Dissatisfied     Web

# %% [markdown]
# #### what is the expression to replace the missing values with the mean value?

# %%
import matplotlib.pyplot as plt

BoxPlot1 = myData.boxplot(column = 'NumOfOrders', vert = True)  # vert = true -> vertical boxplots
BoxPlot1.set(ylabel = 'Y_label') #set the y label

plt.show()

# %%
q1 = myData['NumOfOrders'].quantile(0.25) # Q1 of the midterm score
q2 = myData['NumOfOrders'].quantile(0.50) #Q2 (median value)
q3 = myData['NumOfOrders'].quantile(0.75) #Q3
IQR = q3 - q1

lower_fence = q1 - 1.5 * IQR
upper_fence = q3 + 1.5 * IQR


print("min:", myData['NumOfOrders'].min())
print('max:', myData['NumOfOrders'].max())
print("Q1:", q1)
print("Q2 (median):", q2)
print("Q3:", q3)
print("IQR:", IQR)

print("low_fence:", lower_fence) #Low fence value
print("High_fense:", upper_fence) #High fence value
# Out:
# min: 1
# max: 89
# Q1: 4.0
# Q2 (median): 9.0
# Q3: 15.0
# IQR: 11.0
# low_fence: -12.5
# High_fense: 31.5

# %% [markdown]
# ### Can you find the followings?
# *   the low whisker and high whisker values
# *   outliers (if any)

# %%
# find the high whisker value for numOfOrders

numOfOrders_less_than_upper_fence = myData[myData['NumOfOrders'] <= upper_fence]

# Among the midterm scores less than the midterm score upper fence, find the max value
whisker_high = numOfOrders_less_than_upper_fence['NumOfOrders'].max()

print(whisker_high)
# Out:
# 31

# %%
# fin the low whister value for NumOfOrders

numOfOrders_higher_than_lower_fence = myData[myData['NumOfOrders'] >= lower_fence]

# Among the midterm scores less than the midterm score upper fence, find the max value
whisker_low = numOfOrders_higher_than_lower_fence['NumOfOrders'].min()

print(whisker_low)
# Out:
# 1

# %%
#Mean or median of the column Income?
myData['Income'].mean() #or median(), max(), min()
# Out:
# np.float64(73036.5296803653)

# %% [markdown]
# ### Row Subsetting using boolean expression

# %%
high_spending_cust = (myData['Spending2020'] > 800 ) &  (myData['Spending2021'] > 800)

high_spending_cust = myData[ (myData['Spending2020'] > 1000) |  (myData['Spending2021'] > 1000)  ]

# & --> and operator,   | --> or operator


high_spending_cust
# Out:
#       CustID     Sex              Race   BirthDate College  HouseholdSize  \
# 1    1531136    Male             White    5/9/1993     Yes              5
# 7    1533561    Male          Hispanic   2/10/1981     Yes              5
# 10   1533791    Male             White  10/27/1999     Yes              1
# 17   1535927    Male             White   1/12/1979     Yes              1
# 18   1536475    Male  Pacific Islander   5/17/1958     Yes              2
# ..       ...     ...               ...         ...     ...            ...
# 207  1576752    Male             Black   7/18/1968     Yes              4
# 211  1577940  Female             Black   2/27/1973     Yes              5
# 212  1578327    Male          Hispanic   8/24/1967     Yes              1
# 214  1578525    Male          Hispanic  12/12/1963     Yes              1
# 218  1579979    Male             White    7/5/1999     Yes              5
#
#      ZipCode  Income  Spending2020  Spending2021  NumOfOrders  DaysSinceLast  \
# 1      90026   94000        1227.0         843.0           12            262
# 7      90050   76000        1474.0        1079.0           23            122
# 10     90060   97000         828.0        1028.0           17            110
# 17     90003   66000        1283.0         879.0           10             35
# 18     90019   73000        1276.0        1108.0           20             56
# ..       ...     ...           ...           ...          ...            ...
# 207    90044   82000        1322.0        1241.0           11            159
# 211    90019   94000         634.0        1206.0           18            181
# 212    90024   49000        1015.0         760.0           11            136
# 214    90005   82000           NaN        1121.0           25            302
# 218    90043  102000        1080.0         926.0           10            113
#
#            Satisfaction   Channel
# 1               Neutral        TV
# 7        Very Satisfied  Referral
# 10    Very Dissatisfied       Web
# 17       Very Satisfied  Referral
# 18              Neutral       Web
# ..                  ...       ...
# 207      Very Satisfied        TV
# 211  Somewhat Satisfied       Web
# 212             Neutral        SM
# 214  Somewhat Satisfied       Web
# 218  Somewhat Satisfied        SM
#
# [64 rows x 14 columns]

# %%
high_spending_cust.shape # or len(high_spending_cust)
# Out:
# (64, 14)

# %% [markdown]
# ### Groupby

# %%
myData.groupby('Channel')['Spending2020'].mean()

#from this, what can we infer? socail media, TV or Web --> which one should we emphaize
# Out:
# Channel
# Referral    629.097561
# SM          673.000000
# TV          693.824561
# Web         597.915493
# Name: Spending2020, dtype: float64

# %%
#standard deviation

myData.Income.std()
# Out:
# 24060.29388910448

# %% [markdown]
# ### Can you find the correlation Coefficient (r) or covirance between "HouseholdSize" and "Income"?

# %%
myData[['Income', 'HouseholdSize']].corr()
# Out:
#                  Income  HouseholdSize
# Income         1.000000       0.163175
# HouseholdSize  0.163175       1.000000

# %%
myData[['Income', 'HouseholdSize']].cov()
# Out:
#                      Income  HouseholdSize
# Income         5.788977e+08    5611.495120
# HouseholdSize  5.611495e+03       2.042897

# %%
# Any missing values?

myData.isnull().sum()
# Out:
# CustID           0
# Sex              0
# Race             0
# BirthDate        0
# College          0
# HouseholdSize    0
# ZipCode          0
# Income           0
# Spending2020     7
# Spending2021     5
# NumOfOrders      0
# DaysSinceLast    0
# Satisfaction     0
# Channel          0
# dtype: int64

# %% [markdown]
# #### How to replace the missing values? --> look at ch2.ipynb file --> fillna

# %%
imputation = myData.Spending2021.fillna(myData.Spending2021.mean()) #still original dataframe myData remains unchanged.
imputation

#To permanently change the original data frame, myData:

#myData['Spending2021'] = myData.Spending2021.mean() -> Be careful! -> this will change your original dataframe forever~
# Out:
# 0       241.0
# 1       843.0
# 2       719.0
# 3       582.0
# 4       845.0
#         ...
# 214    1121.0
# 215     397.0
# 216     514.0
# 217     586.0
# 218     926.0
# Name: Spending2021, Length: 219, dtype: float64
