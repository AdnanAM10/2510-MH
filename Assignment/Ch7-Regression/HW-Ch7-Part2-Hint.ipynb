# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Exercise 7-20

# %%
import pandas as pd

myData = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/Assignment/Ch7-Regression/Ch7_Q20_Data_File.xlsx')

print(myData.head(n=10))
# Out:
#    Months  Age  Income    Plan
# 0      11   39     134  Single
# 1      41   57     120  Family
# 2      29   72      75  Single
# 3      52   71     143  Single
# 4      46   25      75  Single
# 5      48   44     149  Single
# 6       1   21     113  Family
# 7      54   26      87  Family
# 8      11   63      44  Family
# 9       3   37      44  Single

# %%
myData['Single'] = myData['Plan'].apply(lambda x: 1 if x == 'Single' else 0)

print(myData.head())
# Out:
#    Months  Age  Income    Plan  Single
# 0      11   39     134  Single       1
# 1      41   57     120  Family       0
# 2      29   72      75  Single       1
# 3      52   71     143  Single       1
# 4      46   25      75  Single       1

# %%
import statsmodels.formula.api as smf

# Hint: Review my lecture note (MH-Ch7.ipynb)

#For the model 1

# Hint: smf.ols('Months ~ Income + Single', data = myData).fit()

# %%
# For the model 2
# Hint: Review my lecture note (MH-Ch7.ipynb)

# Hint: smf.ols('Months ~ Income+Single+Age', data = myData).fit()

# %% [markdown]
# ### If you care about full-precision output for the assignment (round your answer to 2 decimal places --> See my lecture note (MH-Ch7.ipynb)

# %% [markdown]
# # Exercise 7-21

# %%
import pandas as pd

#Hint: pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/Assignment/Ch7-Regression/Ch7_Q21_Data_File.xlsx')

# %%
import statsmodels.formula.api as smf

# fill out the rest

# Hint:  smf.ols('Final ~ Midterm', .......)

# %%
import numpy as np

# See my lecture note on Ch7 (how to get the standard error)

# Hint: To compute the standard error, plesae use: mse_resid attribute

# %% [markdown]
# ### If you care about full-precision output for the assignment (round your answer to 2 decimal places --> See my lecture note (MH-Ch7.ipynb)
