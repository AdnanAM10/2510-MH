# %%
#Mount the google drive  how to mount?
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
myData = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/MH-Ch2/jaggia_ba_2025_ch02_data.xlsx", sheet_name = 'Spend')
myData
# Out:
#       ID OwnHome OwnCar  FoodSpend  TravelSpend
# 0      1     Yes    Yes    5472.43       827.40
# 1      2      No    Yes    9130.73       863.55
# 2      3      No    Yes    4450.67      1180.05
# 3      4      No    Yes    5020.72       755.70
# 4      5      No    Yes    3408.11       851.40
# ..   ...     ...    ...        ...          ...
# 495  496     Yes     No    3787.29      2058.75
# 496  497      No     No    6460.84      3852.90
# 497  498      No     No    3585.86      2251.95
# 498  499     Yes     No    1833.95      2000.25
# 499  500      No     No    6205.97      3667.50
#
# [500 rows x 5 columns]

# %%
sortedData = myData.sort_values(['OwnHome', 'OwnCar', 'TravelSpend'], ascending = [False, False, False])
sortedData.head(n=10) #show the first 10 rows
# Out:
#       ID OwnHome OwnCar  FoodSpend  TravelSpend
# 197  198     Yes    Yes    3362.86      5616.00
# 425  426     Yes    Yes    2275.24      2437.95
# 31    32     Yes    Yes    4070.45      2386.80
# 319  320     Yes    Yes    2482.76      2309.25
# 378  379     Yes    Yes    2482.76      2309.25
# 293  294     Yes    Yes    4843.94      2250.60
# 389  390     Yes    Yes    3699.42      2122.20
# 29    30     Yes    Yes    2260.17      1905.90
# 82    83     Yes    Yes    2044.21      1856.10
# 373  374     Yes    Yes    2044.21      1856.10

# %%
#c missing value in Home Ownership
pd.isna(myData.OwnHome)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: OwnHome, Length: 500, dtype: bool

# %%
# how many customers are carowners?
(myData.OwnCar =='Yes').sum()
# Out:
# np.int64(162)

# %%
#How many customers are car owners but not home owners?
#Note: you have to use and opertor --> &, not or operator --> |
df2 = ((myData.OwnHome == 'No') & (myData.OwnCar == 'Yes'))
df2
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
df2.sum()
# Out:
# np.int64(117)

# %%
#How many customers have an annual household spending on travel greater than $XXXX
#and an annual household spending on food greater than $YYYY
#
#((myData.TravelSpend > XXXX) & ..........YYYY)).sum()
# Out:
# np.int64(12)
