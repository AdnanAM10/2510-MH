# %%
# Mount google driv
from google.colab import drive
drive.mount('/content/drive')#
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
myData = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/Assignment/Ch2/Ch2-Customers.csv')
myData.head(n=10)
# Out:
#     CustID     Sex      Race   BirthDate College  HouseholdSize  ZipCode  \
# 0  1530016  Female     Black  12/16/1986     Yes              5    90047
# 1  1531136    Male     White    5/9/1993     Yes              5    90026
# 2  1532160    Male     Black   5/22/1966     Yes              2    90027
# 3  1532307    Male     White   9/16/1964     Yes              4    90029
# 4  1532356  Female  Hispanic   7/15/1964      No              5    90017
# 5  1532387    Male     White   8/27/1957     Yes              2    90028
# 6  1533017  Female  Hispanic   5/14/1985     Yes              3    90063
# 7  1533561    Male  Hispanic   2/10/1981     Yes              5    90050
# 8  1533697  Female     Asian   10/8/1974     Yes              3    90038
# 9  1533766    Male  Hispanic   9/16/1971     Yes              2    90057
#
#    Income  Spending2020  Spending2021  NumOfOrders  DaysSinceLast  \
# 0   53000         287.0         241.0            3            101
# ...

# %%
#Missing values in the column, Spending2021.

# Note: The CSV has two similar columns, Spending2020 and Spending2021. Don't mix them up!!!

print(pd.isna(myData.Spending2021))
pd.isna(myData.Spending2021).sum()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 214    False
# 215    False
# 216    False
# 217    False
# 218    False
# Name: Spending2021, Length: 219, dtype: bool
# np.int64(4)

# %%
# Mean value of the column, Spending2021?

print(myData["Spending2021"])
mean_Spending2021 = myData["Spending2021"].mean()
print(mean_Spending2021)
# Out:
# 0       241.0
# 1       843.0
# 2       719.0
# 3       582.0
# 4       845.0
#         ...
# 214    1121.0
# 215     397.0
# 216     514.0
# 217     586.0
# 218     926.0
# Name: Spending2021, Length: 219, dtype: float64
# 650.8046511627907

# %%
#Replace the missing values in the column, Spending2020 with the mean value. What is the new mean value after the replacement?
myData['Spending2021'] = myData['Spending2021'].fillna(myData['Spending2021'].mean())
#Permanently change the orgainal dataframe, myData with the assignment =

#Same expression as above:
#myData.Spending2020  = myData.Spending2020.fillna(myData.Spending2020.mean())

myData['Spending2021'].mean() #calculate the mean value after replacement
# Out:
# np.float64(650.8046511627907)

# %%
#Split the data set into a number of subsets based on 'Satisfaction'
myData.groupby('Satisfaction').size()
# Out:
# Satisfaction
# Neutral                   38
# Somewhat Dissatisfied     19
# Somewhat Satisfied       104
# Very Dissatisfied          9
# Very Satisfied            49
# dtype: int64

# %%
# Among "neutral" customers, what is the mean of Spending2020?

myData.groupby('Satisfaction')['Spending2020'].mean()
# Out:
# Satisfaction
# Neutral                  641.000000
# Somewhat Dissatisfied    730.736842
# Somewhat Satisfied       586.851485
# Very Dissatisfied        500.777778
# Very Satisfied           763.632653
# Name: Spending2020, dtype: float64

# %%
# How many male customers spent more than $150 in 2021 and have Income > 80000?
# Row Subsetting using boolean expression

myData[(myData['Sex'] == 'Male') & (myData['Income'] > 80000) & (myData['Spending2021'] > 150)]

# Once you have the resulting dataframe, apply len() to the dataframe or use the .shape attribute to compute the number of male customers.
# Out:
#       CustID   Sex             Race   BirthDate College  HouseholdSize  \
# 1    1531136  Male            White    5/9/1993     Yes              5
# 10   1533791  Male            White  10/27/1999     Yes              1
# 12   1534502  Male         Hispanic  12/26/1989     Yes              2
# 13   1534928  Male         Hispanic   1/18/1959     Yes              5
# 19   1536814  Male            Black   7/25/1962     Yes              5
# 22   1538886  Male  American Indian   9/15/1996     Yes              2
# 24   1539808  Male            Black    8/2/1954     Yes              5
# 28   1540183  Male            White   2/27/1991     Yes              1
# 32   1541742  Male            Black   3/15/1960     Yes              2
# 34   1542099  Male            Asian    7/6/1984     Yes              2
# 39   1543582  Male            White   4/23/1973     Yes              3
# 42   1543988  Male         Hispanic   6/19/1963     Yes              3
# ...
