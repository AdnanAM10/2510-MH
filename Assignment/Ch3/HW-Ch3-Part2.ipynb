# %% [markdown]
# ## Hint Code -
# Please note: the code below is a hint/starter snippet. It’s a good starting point to review and build on, but it is not a complete solution. To arrive at the correct answer, you must modify and extend this code.

# %%
# Mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read the data,

import pandas as pd
myData = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/Assignment/Ch3/Ch3_Q21_Data_File.xlsx', sheet_name="Car_Prices")
myData.head(n=10)
# Out:
#    Price  Age  Miles
# 0  13590    6  61485
# 1  13775    6  54344
# 2  22991    1   8246
# 3  15303    4  24856
# 4  16388    3  22100
# 5  16600    3  23702
# 6  16987    4  47401
# 7  18489    2  16888
# 8  18859    3  35380
# 9  19857    3  29634

# %%
myData[['Age']].mean()

# %%
myData.Age.mean() # Another expression

# %%
myData[['Age']].std()  # Note this std() returns the SAMPLE standard deviation, NOT population standard deviation

# %%
# Correlation Coefficient betweem price and age

myData[['Price', 'Age']].corr()

# Note Covariance between price and ange --> myData[['Price', 'Age']].cov()
# Try -->  myData[['Price', 'Age']].cov()
