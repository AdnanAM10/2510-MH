# %% [markdown]
# ## Hint Code -
#
# Please note: the code below is a hint/starter snippet. It’s a good starting point to review and build on, but it is not a complete solution. To arrive at the correct answer, you must modify and extend this code.

# %%
#mounnt your google dirve
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# read the data,

import pandas as pd
myData = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/2510/2510-MH/Assignment/Ch3/Ch3_Q9_Data_File.xlsx', sheet_name="IceCream")
myData.head(n=10)

# %%
myData.Hours.mean()

# %%
myData['Hours'].mean() # Another equivalent expression

# %%
myData.groupby('Hot').Income.mean()

# %%
#another equivalent expression
myData.groupby('Hot')['Income'].mean()
