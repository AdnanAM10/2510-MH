# %%
fruits = ["apple", "banana", "cherry", "peach", "kiwi", "blueberry" ]
len(fruits)
# Out:
# 6

# %%
#List index starts with 0!
fruits[0]
# Out:
# 'apple'

# %%
midterm_score = [98, 100, 85, 76, 85, 99, 100] # midterm scores of 7 students

final_score = [100, 90, 87, 75,96, 98, 85]

#how can you find the total score? midterm_score + final_score?
print(midterm_score+final_score) #the result --> is this what you expect? --> no elementwise operation!!!
# Out:
# [98, 100, 85, 76, 85, 99, 100, 100, 90, 87, 75, 96, 98, 85]

# %%
x =3
x =5
print(x) #int is immutable!!
# Out:
# 5

# %%
#List and dict are mutable - everythign else --> immutable
fruits[0] = "orange" #List index starts from 0
fruits
# Out:
# ['orange', 'banana', 'cherry', 'peach', 'kiwi', 'blueberry']

# %%
#you can use

# %%
#add list items --> use append or insert
fruits.insert(4,"grape")

fruits.insert(10,"watermelon")
fruits
# Out:
# ['apple',
#  'banana',
#  'cherry',
#  'peach',
#  'grape',
#  'kiwi',
#  'blueberry',
#  'watermelon']

# %%
#Remomve list ->remove and pop
fruits = ["apple", "banana", "cherry", "peach", "kiwi", "blueberry" ]
fruits.remove("apple")
print(fruits)

fruits = ["apple", "banana", "cherry", "peach", "kiwi", "blueberry" ]
fruits.pop(4) # 4 is the index number
print(fruits)
# Out:
# ['banana', 'cherry', 'peach', 'kiwi', 'blueberry']
# ['apple', 'banana', 'cherry', 'peach', 'blueberry']

# %%
#Loop
midterm_score = [98, 100, 78,89,91,92]

for x in midterm_score:
  print (x)
# Out:
# 98
# 100
# 78
# 89
# 91
# 92

# %%
midterm_score = [98, 100, 78,89,91,92]
midterm_score.sort()
midterm_score
# Out:
# [78, 89, 91, 92, 98, 100]

# %%
fruits = ["apple", "banana", "cherry", "peach", "kiwi", "blueberry" ]
fruits.sort()
fruits
# Out:
# ['apple', 'banana', 'blueberry', 'cherry', 'kiwi', 'peach']
