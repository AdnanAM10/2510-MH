# %%
print(10>9)
print(10 == 10)
# Out:
# True
# True

# %%
a = 10
b = 1

if a < b:
  print("a > b")
  print("Hi")
else:
  print("b > a")
# Out:
# b > a

# %%
x =3
x += 10 # x = x+ 10
x
# Out:
# 13

# %%
10//3 # 10/3 = 3.3333333
# Out:
# 3

# %%
#boolean operator

x = 5
y = 1

print((x != y) and (x < y))

print((x != y) or (x < y))
# Out:
# False
# True
