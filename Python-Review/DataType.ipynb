# %%
fruits = { "apple":1.23, "banana":0.56, "cherry":2.15 } #Dictionary example
fruits
# Out:
# {'apple': 1.23, 'banana': 0.56, 'cherry': 2.15}

# %%
y = str(2)
print(y)
print(type(y))
# Out:
# 2
# <class 'str'>

# %%
#Strings are arrays
a = "Hello, World!"
print(a[1])
print(len(a))
# Out:
# e
# 13

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
#Check if "free" is present in the follwoing text:
txt = "The best things in life are free!"
print("free" in txt)
# Out:
# True

# %%
#Check if "expensive" is NOT present in the following txt
txt = "The best things in life are free!"
print("expensive" not in txt)
# Out:
# True

# %%
#slicing
b = "Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
# Negative Indexing
b = "Hello, World!"
print(b[-1])
print(b[-5:-2])
# Out:
# !
# orl

# %%
#Split method returns a list where the text between the specified separator
#becomes the list items
a = "Hello, World!"
print(a.split(","))
# Out:
# ['Hello', ' World!']

# %%
#Formatting
age = 36
txt = "My name is John, and I am {}"
print(txt.format(age))
# Out:
# My name is John, and I am 36

# %%
#Formatting 2
price = 59
txt = f"The price os {price} dollars "
print(txt)
# Out:
# The price os 59 dollars

# %%
myList = ["Hi", "World"]
mySep =", "
x = mySep.join(myList)
print(x)
# Out:
# Hi, World
